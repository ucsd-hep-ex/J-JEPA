# %%
# Basic Python utilities
import os
import sys
import random
import time

# Data handling
import numpy as np
import pandas as pd

# Machine Learning & Deep Learning
import torch
import sklearn

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Utilities for deep learning
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# Scikit-learn utilities
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Set random seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Enable GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Matplotlib settings
# plt.style.use("seaborn-darkgrid")
sns.set_theme(style="darkgrid")
# Out:
# Using device: cuda

# %%
# nldr mask input
data_dir = "/j-jepa-vol/J-JEPA/models/JetClass/mask_input/NLDR/"
val_losses = np.load(data_dir + "val_losses.npy")

plt.plot(val_losses)
plt.show()

# %%
# attn mask output
data_dir = "/j-jepa-vol/J-JEPA/models/JetClass/mask_output/AttnEmb/"
val_losses = np.load(data_dir + "val_losses.npy")

plt.plot(val_losses)
plt.show()

# %%
# attn mask input
data_dir = "/j-jepa-vol/J-JEPA/models/JetClass/mask_input/AttnEmb/"
val_losses = np.load(data_dir + "val_losses.npy")
train_losses_in = np.load(data_dir + "train_losses.npy")
plt.plot(val_losses)
plt.plot(train_losses_in)
plt.legend(["Validation", "Training"])
plt.show()
